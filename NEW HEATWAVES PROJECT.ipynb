# %% [markdown]
# IMPORTING LIBRARIES

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from warnings import filterwarnings
filterwarnings('ignore')

# %% [markdown]
# DATA READING

# %%
# Specify the path to your text file
file_path1 = 'Yendi_1960_2020_dTx_cgf.txt'
file_path2 = 'Navrongo_1960_2020_dTx_cgf.txt'
file_path3 = 'Wa_1960_2020_dTx_cgf.txt'
file_path4 = 'Bole_1960_2020_dTx_cgf.txt'
file_path5 = 'Walewale_1960_2020_dTx_cgf.txt'
file_path6 = 'Tamale_1960_2020_dTx_cgf.txt'

# %% [markdown]
# FIRST WINDOW

# %%
# Read the file into a pandas DataFrame
yendi_1961_1990 = pd.read_csv(file_path1, delim_whitespace=True, header=None, names=["year", "month", "day", "Tmax"]).loc[366:11322] 
Navrongo_1961_1990 = pd.read_csv(file_path2, delim_whitespace=True, header=None, names=["year", "month", "day", "Tmax"]).loc[366:11322]  
Wa_1961_1990 = pd.read_csv(file_path3, delim_whitespace=True, header=None, names=["year", "month", "day", "Tmax"]).loc[366:11322] 
Bole_1961_1990 = pd.read_csv(file_path4, delim_whitespace=True, header=None, names=["year", "month", "day", "Tmax"]).loc[366:11322]  
Walewale_1961_1990 = pd.read_csv(file_path5, delim_whitespace=True, header=None, names=["year", "month", "day", "Tmax"]).loc[366:11322] 
Tamale_1961_1990 = pd.read_csv(file_path6, delim_whitespace=True, header=None, names=["year", "month", "day", "Tmax"]).loc[366:11322]

# %% [markdown]
# GROUPBY YEAR

# %%
annual_yendi_1961_1990 = yendi_1961_1990.groupby('year')['Tmax'].mean().reset_index()
annual_Navrongo_1961_1990 = Navrongo_1961_1990.groupby('year')['Tmax'].mean().reset_index()
annual_Wa_1961_1990 = Wa_1961_1990.groupby('year')['Tmax'].mean().reset_index()
annual_Bole_1961_1990 = Bole_1961_1990.groupby('year')['Tmax'].mean().reset_index()
annual_Walewale_1961_1990 = Walewale_1961_1990.groupby('year')['Tmax'].mean().reset_index()
annual_Tamale_1961_1990 = Tamale_1961_1990.groupby('year')['Tmax'].mean().reset_index()

# %% [markdown]
# ANOMALY CALCULATION

# %%
# Calculate the overall mean and standard deviation for each location
overall_mean_tmax_yendi_1961_1990 = yendi_1961_1990['Tmax'].mean()
overall_std_tmax_yendi_1961_1990 = yendi_1961_1990['Tmax'].std()

overall_mean_tmax_Navrongo_1961_1990 = Navrongo_1961_1990['Tmax'].mean()
overall_std_tmax_Navrongo_1961_1990 = Navrongo_1961_1990['Tmax'].std()

overall_mean_tmax_Wa_1961_1990 = Wa_1961_1990['Tmax'].mean()
overall_std_tmax_Wa_1961_1990 = Wa_1961_1990['Tmax'].std()

overall_mean_tmax_Bole_1961_1990 = Bole_1961_1990['Tmax'].mean()
overall_std_tmax_Bole_1961_1990 = Bole_1961_1990['Tmax'].std()

overall_mean_tmax_Walewale_1961_1990 = Walewale_1961_1990['Tmax'].mean()
overall_std_tmax_Walewale_1961_1990 = Walewale_1961_1990['Tmax'].std()

overall_mean_tmax_Tamale_1961_1990 = Tamale_1961_1990['Tmax'].mean()
overall_std_tmax_Tamale_1961_1990 = Tamale_1961_1990['Tmax'].std()

# Calculate the anomaly for each year for each location
annual_yendi_1961_1990['Anomaly'] = (annual_yendi_1961_1990['Tmax'] - overall_mean_tmax_yendi_1961_1990) / overall_std_tmax_yendi_1961_1990
annual_Navrongo_1961_1990['Anomaly'] = (annual_Navrongo_1961_1990['Tmax'] - overall_mean_tmax_Navrongo_1961_1990) / overall_std_tmax_Navrongo_1961_1990
annual_Wa_1961_1990['Anomaly'] = (annual_Wa_1961_1990['Tmax'] - overall_mean_tmax_Wa_1961_1990) / overall_std_tmax_Wa_1961_1990
annual_Bole_1961_1990['Anomaly'] = (annual_Bole_1961_1990['Tmax'] - overall_mean_tmax_Bole_1961_1990) / overall_std_tmax_Bole_1961_1990
annual_Walewale_1961_1990['Anomaly'] = (annual_Walewale_1961_1990['Tmax'] - overall_mean_tmax_Walewale_1961_1990) / overall_std_tmax_Walewale_1961_1990
annual_Tamale_1961_1990['Anomaly'] = (annual_Tamale_1961_1990['Tmax'] - overall_mean_tmax_Tamale_1961_1990) / overall_std_tmax_Tamale_1961_1990

# Print the result for each location
print("Yendi Anomaly:\n", annual_yendi_1961_1990)
print("Navrongo Anomaly:\n", annual_Navrongo_1961_1990)
print("Wa Anomaly:\n", annual_Wa_1961_1990)
print("Bole Anomaly:\n", annual_Bole_1961_1990)
print("Walewale Anomaly:\n", annual_Walewale_1961_1990)
print("Tamale Anomaly:\n", annual_Tamale_1961_1990)
# Out:
# Yendi Anomaly:
#      year       Tmax   Anomaly
# 0   1961  33.286027 -0.025154
# 1   1962  32.824110 -0.167418
# 2   1963  33.078904 -0.088945
# 3   1964  33.027869 -0.104663
# 4   1965  32.950411 -0.128519
# 5   1966  33.479178  0.034333
# 6   1967  32.795616 -0.176194
# 7   1968  33.027596 -0.104747
# 8   1969  33.372603  0.001510
# 9   1970  33.629041  0.080489
# 10  1971  33.010685 -0.109956
# 11  1972  33.359836 -0.002422
# 12  1973  34.191233  0.253636
# 13  1974  33.190685 -0.054518
# 14  1975  33.113151 -0.078398
# 15  1976  32.807377 -0.172572
# 16  1977  33.452603  0.026148
# 17  1978  32.926301 -0.135945
# 18  1979  33.515068  0.045387
# 19  1980  33.773224  0.124895
# 20  1981  33.920274  0.170184
# 21  1982  33.150685 -0.066838
# 22  1983  33.853699  0.149680
# 23  1984  33.453552  0.026441
# 24  1985  33.167123 -0.061775
# 25  1986  33.220548 -0.045321
# 26  1987  34.332877  0.297260
# 27  1988  33.536066  0.051854
# 28  1989  33.469863  0.031464
# 29  1990  34.116438  0.230600
# Navrongo Anomaly:
#      year       Tmax   Anomaly
# 0   1961  34.276986 -0.085782
# 1   1962  34.014027 -0.159419
# 2   1963  34.324932 -0.072356
# 3   1964  34.290164 -0.082092
# 4   1965  34.651233  0.019018
# 5   1966  34.718356  0.037815
# 6   1967  33.083836 -0.419901
# 7   1968  32.634098 -0.545841
# 8   1969  33.212932 -0.383750
# 9   1970  35.114521  0.148753
# 10  1971  34.287671 -0.082790
# 11  1972  34.348907 -0.065642
# 12  1973  35.125205  0.151745
# 13  1974  34.315068 -0.075118
# 14  1975  34.409315 -0.048726
# 15  1976  34.225410 -0.100225
# 16  1977  34.883836  0.084154
# 17  1978  34.620000  0.010272
# 18  1979  34.820274  0.066355
# 19  1980  35.218033  0.177739
# 20  1981  35.375068  0.221714
# 21  1982  34.533425 -0.013972
# 22  1983  35.337260  0.211127
# 23  1984  34.832787  0.069859
# 24  1985  34.973425  0.109242
# 25  1986  34.812877  0.064283
# 26  1987  35.742466  0.324597
# 27  1988  34.985519  0.112628
# 28  1989  34.942192  0.100495
# 29  1990  35.393973  0.227008
# Wa Anomaly:
#      year       Tmax   Anomaly
# 0   1961  32.821918 -0.128161
# 1   1962  32.482740 -0.233611
# 2   1963  32.983562 -0.077906
# 3   1964  32.768579 -0.144744
# 4   1965  32.970411 -0.081995
# 5   1966  33.159452 -0.023222
# 6   1967  32.960548 -0.085061
# 7   1968  32.629781 -0.187896
# 8   1969  33.410959  0.054971
# 9   1970  33.562192  0.101989
# 10  1971  32.986027 -0.077140
# 11  1972  33.152459 -0.025396
# 12  1973  33.903288  0.208035
# 13  1974  32.858767 -0.116705
# 14  1975  32.909041 -0.101075
# 15  1976  32.623251 -0.189926
# 16  1977  33.302740  0.021326
# 17  1978  33.155342 -0.024500
# 18  1979  33.370411  0.042364
# 19  1980  33.313934  0.024806
# 20  1981  33.698082  0.144237
# 21  1982  33.077260 -0.048776
# 22  1983  33.536384  0.093965
# 23  1984  33.539071  0.094801
# 24  1985  33.142466 -0.028503
# 25  1986  33.397534  0.050797
# 26  1987  34.187945  0.296534
# 27  1988  33.682514  0.139397
# 28  1989  33.465205  0.071836
# 29  1990  33.975068  0.230351
# Bole Anomaly:
#      year       Tmax   Anomaly
# 0   1961  32.773205  0.111363
# 1   1962  31.883562 -0.172678
# 2   1963  32.352055 -0.023100
# 3   1964  32.029235 -0.126168
# 4   1965  32.346849 -0.024762
# 5   1966  32.653973  0.073295
# 6   1967  32.075068 -0.111535
# 7   1968  32.035246 -0.124249
# 8   1969  32.406849 -0.005606
# 9   1970  32.074548 -0.111701
# 10  1971  31.010767 -0.451339
# 11  1972  31.698907 -0.231633
# 12  1973  32.452411  0.008941
# 13  1974  31.857781 -0.180909
# 14  1975  31.666548 -0.241965
# 15  1976  31.385656 -0.331647
# 16  1977  32.930137  0.161467
# 17  1978  32.384658 -0.012691
# 18  1979  32.684658  0.083092
# 19  1980  32.570219  0.046554
# 20  1981  32.817260  0.125428
# 21  1982  32.456986  0.010402
# 22  1983  33.284932  0.274744
# 23  1984  32.904372  0.153241
# 24  1985  32.603014  0.057025
# 25  1986  32.603014  0.057025
# 26  1987  33.765753  0.428258
# 27  1988  33.008470  0.186477
# 28  1989  32.897260  0.150970
# 29  1990  33.122466  0.222873
# Walewale Anomaly:
#      year       Tmax   Anomaly
# 0   1961  34.130849  0.094275
# 1   1962  33.494466 -0.081733
# 2   1963  33.639479 -0.041625
# 3   1964  34.138470  0.096383
# 4   1965  33.478356 -0.086188
# 5   1966  34.332877  0.150151
# 6   1967  33.203644 -0.162167
# 7   1968  32.749672 -0.287724
# 8   1969  33.029068 -0.210450
# 9   1970  33.668082 -0.033715
# 10  1971  32.934438 -0.236622
# 11  1972  33.989508  0.055184
# 12  1973  35.460274  0.461961
# 13  1974  34.736411  0.261758
# 14  1975  33.900301  0.030511
# 15  1976  32.717732 -0.296557
# 16  1977  33.504055 -0.079080
# 17  1978  33.138438 -0.180201
# 18  1979  33.097178 -0.191612
# 19  1980  33.235191 -0.153441
# 20  1981  33.782329 -0.002117
# 21  1982  33.619342 -0.047195
# 22  1983  34.595671  0.222833
# 23  1984  34.691038  0.249209
# 24  1985  33.886575  0.026715
# 25  1986  34.060219  0.074741
# 26  1987  34.807945  0.281543
# 27  1988  33.784727 -0.001454
# 28  1989  33.609205 -0.049998
# 29  1990  34.287288  0.137542
# Tamale Anomaly:
#      year       Tmax   Anomaly
# 0   1961  33.621644 -0.070161
# 1   1962  33.292877 -0.169825
# 2   1963  33.486301 -0.111189
# 3   1964  33.234973 -0.187378
# 4   1965  33.429041 -0.128547
# 5   1966  33.655068 -0.060029
# 6   1967  33.165479 -0.208444
# 7   1968  33.348634 -0.152922
# 8   1969  34.112055  0.078504
# 9   1970  34.403014  0.166706
# 10  1971  33.366027 -0.147650
# 11  1972  33.752732 -0.030423
# 12  1973  35.145479  0.391779
# 13  1974  33.583562 -0.081706
# 14  1975  33.492603 -0.109279
# 15  1976  33.396721 -0.138345
# 16  1977  33.907671  0.016546
# 17  1978  33.609589 -0.073815
# 18  1979  34.035342  0.055249
# 19  1980  34.041858  0.057224
# 20  1981  34.361123  0.154007
# 21  1982  33.647370 -0.062362
# 22  1983  34.618548  0.232044
# 23  1984  34.054918  0.061183
# 24  1985  33.368795 -0.146811
# 25  1986  33.991781  0.042043
# 26  1987  34.905205  0.318942
# 27  1988  34.079508  0.068637
# 28  1989  34.005479  0.046196
# 29  1990  34.482192  0.190708

# %%
import matplotlib.pyplot as plt

# Create a plot with a figure and axis
plt.figure(figsize=(10, 6))

# Plot the anomalies for each location
plt.plot(annual_yendi_1961_1990['year'], annual_yendi_1961_1990['Anomaly'], label="Yendi", marker='o')
plt.plot(annual_Navrongo_1961_1990['year'], annual_Navrongo_1961_1990['Anomaly'], label="Navrongo", marker='s')
plt.plot(annual_Wa_1961_1990['year'], annual_Wa_1961_1990['Anomaly'], label="Wa", marker='^')
plt.plot(annual_Bole_1961_1990['year'], annual_Bole_1961_1990['Anomaly'], label="Bole", marker='d')
plt.plot(annual_Walewale_1961_1990['year'], annual_Walewale_1961_1990['Anomaly'], label="Walewale", marker='x')
plt.plot(annual_Tamale_1961_1990['year'], annual_Tamale_1961_1990['Anomaly'], label="Tamale", marker='*')

# Add a horizontal line at y=0 (zero anomaly line)
plt.axhline(y=0, color='black', linestyle='--')

# Set plot title and labels
plt.title('TEMPERATURE ANOMALIES(1961 - 1990) FOR SELECTED LOCATIONS')
plt.xlabel('YEAR')
plt.ylabel('ANOMALY (Tmax)')

# Add a legend to differentiate locations
plt.legend()

# Display the plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set a color palette for the plot
sns.set_palette("Set1")

# Create a plot with a figure and axis
plt.figure(figsize=(12, 7))

# Plot the anomalies for each location with improved styles
plt.plot(annual_yendi_1961_1990['year'], annual_yendi_1961_1990['Anomaly'], label="Yendi", marker='o', markersize=6, linewidth=2)
plt.plot(annual_Navrongo_1961_1990['year'], annual_Navrongo_1961_1990['Anomaly'], label="Navrongo", marker='s', markersize=6, linewidth=2)
plt.plot(annual_Wa_1961_1990['year'], annual_Wa_1961_1990['Anomaly'], label="Wa", marker='^', markersize=6, linewidth=2)
plt.plot(annual_Bole_1961_1990['year'], annual_Bole_1961_1990['Anomaly'], label="Bole", marker='d', markersize=6, linewidth=2)
plt.plot(annual_Walewale_1961_1990['year'], annual_Walewale_1961_1990['Anomaly'], label="Walewale", marker='x', markersize=6, linewidth=2)
plt.plot(annual_Tamale_1961_1990['year'], annual_Tamale_1961_1990['Anomaly'], label="Tamale", marker='*', markersize=6, linewidth=2)

# Add a horizontal line at y=0 (zero anomaly line)
plt.axhline(y=0, color='black', linestyle='--', linewidth=1.5)

# Add gridlines to the plot
plt.grid(True, which='both', linestyle='--', linewidth=0.5)

# Set plot title and labels with improved font sizes
plt.title('Temperature Anomalies (1961-1990) for Selected Locations', fontsize=16, fontweight='bold')
plt.xlabel('Year', fontsize=14)
plt.ylabel('Anomaly (Tmax)', fontsize=14)

# Customize the legend
plt.legend(title='Locations', fontsize=12, title_fontsize=14, loc='upper left')

# Adjust the ticks on the axes for better readability
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

# Apply a tight layout
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# SECOND WINDOW

# %%
# Read the file into a pandas DataFrame
yendi_1991_2020 = pd.read_csv(file_path1, delim_whitespace=True, header=None, names=["year", "month", "day", "Tmax"]).loc[11323:22280] 
Navrongo_1991_2020 = pd.read_csv(file_path2, delim_whitespace=True, header=None, names=["year", "month", "day", "Tmax"]).loc[11323:22280]  
Wa_1991_2020 = pd.read_csv(file_path3, delim_whitespace=True, header=None, names=["year", "month", "day", "Tmax"]).loc[11323:22280] 
Bole_1991_2020 = pd.read_csv(file_path4, delim_whitespace=True, header=None, names=["year", "month", "day", "Tmax"]).loc[11323:22280]  
Walewale_1991_2020 = pd.read_csv(file_path5, delim_whitespace=True, header=None, names=["year", "month", "day", "Tmax"]).loc[11323:22280] 
Tamale_1991_2020 = pd.read_csv(file_path6, delim_whitespace=True, header=None, names=["year", "month", "day", "Tmax"]).loc[11323:22280]

# %% [markdown]
# GROUPBY YEAR

# %%
annual_yendi_1991_2020 = yendi_1991_2020.groupby('year')['Tmax'].mean().reset_index()
annual_Navrongo_1991_2020 = Navrongo_1991_2020.groupby('year')['Tmax'].mean().reset_index()
annual_Wa_1991_2020 = Wa_1991_2020.groupby('year')['Tmax'].mean().reset_index()
annual_Bole_1991_2020 = Bole_1991_2020.groupby('year')['Tmax'].mean().reset_index()
annual_Walewale_1991_2020 = Walewale_1991_2020.groupby('year')['Tmax'].mean().reset_index()
annual_Tamale_1991_2020 = Tamale_1991_2020.groupby('year')['Tmax'].mean().reset_index()

# %%
# Calculate the overall mean and standard deviation for each location
overall_mean_tmax_yendi_1991_2020 = yendi_1991_2020['Tmax'].mean()
overall_std_tmax_yendi_1991_2020 = yendi_1991_2020['Tmax'].std()

overall_mean_tmax_Navrongo_1991_2020 = Navrongo_1991_2020['Tmax'].mean()
overall_std_tmax_Navrongo_1991_2020 = Navrongo_1991_2020['Tmax'].std()

overall_mean_tmax_Wa_1991_2020 = Wa_1991_2020['Tmax'].mean()
overall_std_tmax_Wa_1991_2020 = Wa_1991_2020['Tmax'].std()

overall_mean_tmax_Bole_1991_2020 = Bole_1991_2020['Tmax'].mean()
overall_std_tmax_Bole_1991_2020 = Bole_1991_2020['Tmax'].std()

overall_mean_tmax_Walewale_1991_2020 = Walewale_1991_2020['Tmax'].mean()
overall_std_tmax_Walewale_1991_2020 = Walewale_1991_2020['Tmax'].std()

overall_mean_tmax_Tamale_1991_2020 = Tamale_1991_2020['Tmax'].mean()
overall_std_tmax_Tamale_1991_2020 = Tamale_1991_2020['Tmax'].std()

# Calculate the anomaly for each year for each location
annual_yendi_1991_2020['Anomaly'] = (annual_yendi_1991_2020['Tmax'] - overall_mean_tmax_yendi_1991_2020) / overall_std_tmax_yendi_1991_2020
annual_Navrongo_1991_2020['Anomaly'] = (annual_Navrongo_1991_2020['Tmax'] - overall_mean_tmax_Navrongo_1991_2020) / overall_std_tmax_Navrongo_1991_2020
annual_Wa_1991_2020['Anomaly'] = (annual_Wa_1991_2020['Tmax'] - overall_mean_tmax_Wa_1991_2020) / overall_std_tmax_Wa_1991_2020
annual_Bole_1991_2020['Anomaly'] = (annual_Bole_1991_2020['Tmax'] - overall_mean_tmax_Bole_1991_2020) / overall_std_tmax_Bole_1991_2020
annual_Walewale_1991_2020['Anomaly'] = (annual_Walewale_1991_2020['Tmax'] - overall_mean_tmax_Walewale_1991_2020) / overall_std_tmax_Walewale_1991_2020
annual_Tamale_1991_2020['Anomaly'] = (annual_Tamale_1991_2020['Tmax'] - overall_mean_tmax_Tamale_1991_2020) / overall_std_tmax_Tamale_1991_2020

# Print the result for each location
print("Yendi Anomaly:\n", annual_yendi_1991_2020)
print("Navrongo Anomaly:\n", annual_Navrongo_1991_2020)
print("Wa Anomaly:\n", annual_Wa_1991_2020)
print("Bole Anomaly:\n", annual_Bole_1991_2020)
print("Walewale Anomaly:\n", annual_Walewale_1991_2020)
print("Tamale Anomaly:\n", annual_Tamale_1991_2020)
# Out:
# Yendi Anomaly:
#      year       Tmax   Anomaly
# 0   1991  33.276712 -0.224864
# 1   1992  33.524590 -0.152442
# 2   1993  33.987945 -0.017064
# 3   1994  33.948055 -0.028719
# 4   1995  34.098356  0.015194
# 5   1996  34.427869  0.111467
# 6   1997  34.009808 -0.010677
# 7   1998  34.821918  0.226596
# 8   1999  34.274521  0.066664
# 9   2000  34.136612  0.026371
# 10  2001  34.546575  0.146150
# 11  2002  34.384932  0.098922
# 12  2003  34.391781  0.100924
# 13  2004  33.772951 -0.079879
# 14  2005  33.941918 -0.030512
# 15  2006  34.514493  0.136776
# 16  2007  33.890685 -0.045481
# 17  2008  34.077760  0.009176
# 18  2009  34.045205 -0.000335
# 19  2010  34.358082  0.091078
# 20  2011  34.449863  0.117893
# 21  2012  33.471612 -0.167921
# 22  2013  33.365205 -0.199009
# 23  2014  34.005452 -0.011950
# 24  2015  34.577260  0.155115
# 25  2016  34.512842  0.136294
# 26  2017  34.540822  0.144469
# 27  2018  33.033671 -0.295873
# 28  2019  33.597890 -0.131026
# 29  2020  33.408005 -0.186505
# Navrongo Anomaly:
#      year       Tmax   Anomaly
# 0   1991  34.772329 -0.117746
# 1   1992  34.501093 -0.190825
# 2   1993  35.446849  0.063989
# 3   1994  34.727589 -0.129800
# 4   1995  35.299726  0.024350
# 5   1996  35.358743  0.040251
# 6   1997  35.060274 -0.040165
# 7   1998  35.458082  0.067016
# 8   1999  35.262740  0.014385
# 9   2000  35.402459  0.052029
# 10  2001  35.889589  0.183276
# 11  2002  35.544110  0.090194
# 12  2003  35.602192  0.105843
# 13  2004  35.150273 -0.015917
# 14  2005  35.847945  0.172056
# 15  2006  35.618630  0.110272
# 16  2007  34.997808 -0.056995
# 17  2008  35.015847 -0.052135
# 18  2009  35.317534  0.029148
# 19  2010  35.464110  0.068640
# 20  2011  35.408493  0.053655
# 21  2012  34.671585 -0.144889
# 22  2013  35.125342 -0.022634
# 23  2014  35.444055  0.063236
# 24  2015  36.163288  0.257019
# 25  2016  36.007923  0.215159
# 26  2017  35.436110  0.061096
# 27  2018  34.015205 -0.321737
# 28  2019  34.131370 -0.290439
# 29  2020  34.143087 -0.287282
# Wa Anomaly:
#      year       Tmax   Anomaly
# 0   1991  33.587397 -0.069450
# 1   1992  33.611749 -0.062128
# 2   1993  33.805205 -0.003961
# 3   1994  33.585479 -0.070026
# 4   1995  33.805479 -0.003879
# 5   1996  33.909016  0.027252
# 6   1997  33.645205 -0.052068
# 7   1998  34.109863  0.087641
# 8   1999  33.491233 -0.098363
# 9   2000  33.553005 -0.079790
# 10  2001  34.447945  0.189292
# 11  2002  34.104932  0.086158
# 12  2003  33.978356  0.048100
# 13  2004  33.874044  0.016737
# 14  2005  34.183562  0.109800
# 15  2006  34.448493  0.189457
# 16  2007  33.975890  0.047359
# 17  2008  33.894262  0.022816
# 18  2009  33.868767  0.015150
# 19  2010  34.478630  0.198518
# 20  2011  34.170137  0.105763
# 21  2012  33.514754 -0.091291
# 22  2013  33.752301 -0.019868
# 23  2014  34.161123  0.103053
# 24  2015  34.672329  0.256758
# 25  2016  33.644836 -0.052179
# 26  2017  33.525068 -0.088190
# 27  2018  32.705863 -0.334501
# 28  2019  32.977781 -0.252743
# 29  2020  33.072705 -0.224202
# Bole Anomaly:
#      year       Tmax   Anomaly
# 0   1991  32.434521 -0.187241
# 1   1992  32.820219 -0.076924
# 2   1993  32.851781 -0.067896
# 3   1994  33.026027 -0.018058
# 4   1995  33.105014  0.004533
# 5   1996  33.075410 -0.003934
# 6   1997  33.239726  0.043064
# 7   1998  33.746301  0.187954
# 8   1999  33.133973  0.012816
# 9   2000  32.980601 -0.031051
# 10  2001  33.540822  0.129183
# 11  2002  33.309589  0.063046
# 12  2003  33.201096  0.032015
# 13  2004  32.911202 -0.050901
# 14  2005  33.280274  0.054661
# 15  2006  33.503288  0.118448
# 16  2007  33.605205  0.147598
# 17  2008  33.444536  0.101643
# 18  2009  33.358082  0.076916
# 19  2010  33.619452  0.151673
# 20  2011  33.491507  0.115078
# 21  2012  32.732514 -0.102009
# 22  2013  31.065918 -0.578688
# 23  2014  32.564247 -0.150137
# 24  2015  33.084959 -0.001203
# 25  2016  33.363033  0.078332
# 26  2017  33.596137  0.145004
# 27  2018  32.449260 -0.183025
# 28  2019  32.824137 -0.075803
# 29  2020  33.316284  0.064961
# Walewale Anomaly:
#      year       Tmax   Anomaly
# 0   1991  33.350575 -0.327776
# 1   1992  33.583743 -0.265258
# 2   1993  34.027671 -0.146229
# 3   1994  33.597562 -0.261552
# 4   1995  34.396603 -0.047310
# 5   1996  34.573224  0.000047
# 6   1997  34.559863 -0.003536
# 7   1998  35.199726  0.168027
# 8   1999  33.587808 -0.264168
# 9   2000  34.621311  0.012940
# 10  2001  35.202192  0.168688
# 11  2002  35.257260  0.183454
# 12  2003  35.372603  0.214380
# 13  2004  35.106284  0.142973
# 14  2005  35.343123  0.206476
# 15  2006  34.752685  0.048165
# 16  2007  34.914493  0.091549
# 17  2008  34.328880 -0.065468
# 18  2009  35.320822  0.200496
# 19  2010  35.417260  0.226354
# 20  2011  35.598904  0.275057
# 21  2012  34.267541 -0.081914
# 22  2013  34.234329 -0.090819
# 23  2014  34.543589 -0.007899
# 24  2015  34.334904 -0.063853
# 25  2016  34.466612 -0.028539
# 26  2017  34.611863  0.010407
# 27  2018  34.175534 -0.106584
# 28  2019  34.348027 -0.060334
# 29  2020  34.100710 -0.126646
# Tamale Anomaly:
#      year       Tmax   Anomaly
# 0   1991  34.082740 -0.061425
# 1   1992  34.400820  0.029569
# 2   1993  34.483014  0.053083
# 3   1994  34.168055 -0.037018
# 4   1995  34.330411  0.009427
# 5   1996  34.612760  0.090200
# 6   1997  34.290411 -0.002016
# 7   1998  34.915452  0.176792
# 8   1999  34.382192  0.024240
# 9   2000  34.200000 -0.027880
# 10  2001  34.761096  0.132635
# 11  2002  34.813973  0.147761
# 12  2003  34.564384  0.076361
# 13  2004  34.130273 -0.047827
# 14  2005  34.412877  0.033019
# 15  2006  34.690411  0.112414
# 16  2007  34.371507  0.021184
# 17  2008  34.099454 -0.056643
# 18  2009  34.416712  0.034116
# 19  2010  34.444027  0.041930
# 20  2011  34.065918 -0.066237
# 21  2012  33.737842 -0.160091
# 22  2013  34.231890 -0.018757
# 23  2014  33.655123 -0.183754
# 24  2015  33.758027 -0.154316
# 25  2016  35.172623  0.250362
# 26  2017  34.860192  0.160983
# 27  2018  33.482247 -0.233210
# 28  2019  33.704329 -0.169678
# 29  2020  33.685874 -0.174957

# %%
import matplotlib.pyplot as plt

# Create a figure and subplots
fig, axs = plt.subplots(1, 2, figsize=(20, 7))

# Set a suptitle for the whole figure
fig.suptitle('TEMPERATURE ANOMALIES FOR SELECTED LOCATIONS', fontsize=16, fontweight='bold')

# 1st subplot: Anomalies for 1961-1990
axs[0].plot(annual_yendi_1961_1990['year'], annual_yendi_1961_1990['Anomaly'], label="Yendi", marker='o', markersize=5, linewidth=2)
axs[0].plot(annual_Navrongo_1961_1990['year'], annual_Navrongo_1961_1990['Anomaly'], label="Navrongo", marker='s', markersize=5, linewidth=2)
axs[0].plot(annual_Wa_1961_1990['year'], annual_Wa_1961_1990['Anomaly'], label="Wa", marker='^', markersize=5, linewidth=2)
axs[0].plot(annual_Bole_1961_1990['year'], annual_Bole_1961_1990['Anomaly'], label="Bole", marker='d', markersize=5, linewidth=2)
axs[0].plot(annual_Walewale_1961_1990['year'], annual_Walewale_1961_1990['Anomaly'], label="Walewale", marker='x', markersize=5, linewidth=2)
axs[0].plot(annual_Tamale_1961_1990['year'], annual_Tamale_1961_1990['Anomaly'], label="Tamale", marker='*', markersize=5, linewidth=2)

# Add a horizontal line at y=0 (zero anomaly line)
axs[0].axhline(y=0, color='black', linestyle='--', linewidth=1.5)

# Set title and labels for the first subplot
axs[0].set_title('1961-1990', fontsize=14, fontweight='bold')
axs[0].set_xlabel('Year', fontsize=12, fontweight='bold')
axs[0].set_ylabel('ANOMALY (Tmax[°C])', fontsize=12, fontweight='bold')
axs[0].grid(True, which='both', linestyle='--', linewidth=1.5)
axs[0].legend(loc='best')

# Rotate and customize ticks for the first subplot
# axs[0].tick_params(axis='x',  size=10, weight='bold')
# axs[0].tick_params(axis='y', size=10, weight='bold')

# 2nd subplot: Anomalies for 1991-2020
axs[1].plot(annual_yendi_1991_2020['year'], annual_yendi_1991_2020['Anomaly'], label="Yendi", marker='o', markersize=5, linewidth=2)
axs[1].plot(annual_Navrongo_1991_2020['year'], annual_Navrongo_1991_2020['Anomaly'], label="Navrongo", marker='s', markersize=5, linewidth=2)
axs[1].plot(annual_Wa_1991_2020['year'], annual_Wa_1991_2020['Anomaly'], label="Wa", marker='^', markersize=5, linewidth=2)
axs[1].plot(annual_Bole_1991_2020['year'], annual_Bole_1991_2020['Anomaly'], label="Bole", marker='d', markersize=5, linewidth=2)
axs[1].plot(annual_Walewale_1991_2020['year'], annual_Walewale_1991_2020['Anomaly'], label="Walewale", marker='x', markersize=5, linewidth=2)
axs[1].plot(annual_Tamale_1991_2020['year'], annual_Tamale_1991_2020['Anomaly'], label="Tamale", marker='*', markersize=5, linewidth=2)

# Add a horizontal line at y=0 (zero anomaly line)
axs[1].axhline(y=0, color='black', linestyle='--', linewidth=1.5)

# Set title and labels for the second subplot
axs[1].set_title('1991-2020', fontsize=14, fontweight='bold')
axs[1].set_xlabel('YEAR', fontsize=12, fontweight='bold')
axs[1].set_ylabel('ANOMALY (Tmax[°C])', fontsize=12, fontweight='bold')
axs[1].grid(True, which='both', linestyle='--', linewidth=1.5)
axs[1].legend(loc='best')

# # Rotate and customize ticks for the second subplot
# axs[1].tick_params(axis='x', rotation=90, size=10, weight='bold')
# axs[1].tick_params(axis='y', size=10, weight='bold')

# Apply a tight layout to prevent overlap
plt.tight_layout(rect=[0, 0, 1, 0.96])  # Adjusting for suptitle
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[76], line 10
#       7 fig.suptitle('TEMPERATURE ANOMALIES FOR SELECTED LOCATIONS', fontsize=16, fontweight='bold')
#       9 # 1st subplot: Anomalies for 1961-1990
# ---> 10 axs[0].bar(annual_yendi_1961_1990['year'], annual_yendi_1961_1990['Anomaly'], label="Yendi", marker='o', markersize=5, linewidth=2)
#      11 axs[0].bar(annual_Navrongo_1961_1990['year'], annual_Navrongo_1961_1990['Anomaly'], label="Navrongo", marker='s', markersize=5, linewidth=2)
#      12 axs[0].bar(annual_Wa_1961_1990['year'], annual_Wa_1961_1990['Anomaly'], label="Wa", marker='^', markersize=5, linewidth=2)
#
# File ~\anaconda3\lib\site-packages\matplotlib\__init__.py:1465, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1462 @functools.wraps(func)
#    1463 def inner(ax, *args, data=None, **kwargs):
#    1464     if data is None:
# -> 1465         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1467     bound = new_sig.bind(ax, *args, **kwargs)
#    1468     auto_label = (bound.arguments.get(label_namer)
#    1469                   or bound.kwargs.get(label_namer))
#
# File ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:2532, in Axes.bar(self, x, height, width, bottom, align, **kwargs)
#    2523 for l, b, w, h, c, e, lw, htch, lbl in args:
#    2524     r = mpatches.Rectangle(
#    2525         xy=(l, b), width=w, height=h,
#    2526         facecolor=c,
#    (...)
#    2530         hatch=htch,
#    2531         )
# -> 2532     r._internal_update(kwargs)
#    2533     r.get_path()._interpolation_steps = 100
#    2534     if orientation == 'vertical':
#
# File ~\anaconda3\lib\site-packages\matplotlib\artist.py:1219, in Artist._internal_update(self, kwargs)
#    1212 def _internal_update(self, kwargs):
#    1213     """
#    1214     Update artist properties without prenormalizing them, but generating
#    1215     errors as if calling `set`.
#    1216
#    1217     The lack of prenormalization is to maintain backcompatibility.
#    1218     """
# -> 1219     return self._update_props(
#    1220         kwargs, "{cls.__name__}.set() got an unexpected keyword argument "
#    1221         "{prop_name!r}")
#
# File ~\anaconda3\lib\site-packages\matplotlib\artist.py:1193, in Artist._update_props(self, props, errfmt)
#    1191             func = getattr(self, f"set_{k}", None)
#    1192             if not callable(func):
# -> 1193                 raise AttributeError(
#    1194                     errfmt.format(cls=type(self), prop_name=k))
#    1195             ret.append(func(v))
#    1196 if ret:
#
# AttributeError: Rectangle.set() got an unexpected keyword argument 'marker'

# %%
import matplotlib.pyplot as plt
import numpy as np

# Create a figure and subplots
fig, axs = plt.subplots(1, 2, figsize=(20, 7))

# Set a suptitle for the whole figure
fig.suptitle('TEMPERATURE ANOMALIES FOR SELECTED LOCATIONS', fontsize=16, fontweight='bold')

# Define bar width and positions for each location
bar_width = 0.15
index = np.arange(len(annual_yendi_1961_1990['year']))

# 1st subplot: Anomalies for 1961-1990
axs[0].bar(index, annual_yendi_1961_1990['Anomaly'], width=bar_width, label="Yendi")
axs[0].bar(index + bar_width, annual_Navrongo_1961_1990['Anomaly'], width=bar_width, label="Navrongo")
axs[0].bar(index + 2 * bar_width, annual_Wa_1961_1990['Anomaly'], width=bar_width, label="Wa")
axs[0].bar(index + 3 * bar_width, annual_Bole_1961_1990['Anomaly'], width=bar_width, label="Bole")
axs[0].bar(index + 4 * bar_width, annual_Walewale_1961_1990['Anomaly'], width=bar_width, label="Walewale")
axs[0].bar(index + 5 * bar_width, annual_Tamale_1961_1990['Anomaly'], width=bar_width, label="Tamale")

# Add a horizontal line at y=0 (zero anomaly line)
axs[0].axhline(y=0, color='black', linestyle='--', linewidth=1.5)

# Set title and labels for the first subplot
axs[0].set_title('1961-1990', fontsize=14, fontweight='bold')
axs[0].set_xlabel('YEAR', fontsize=12, fontweight='bold')
axs[0].set_ylabel('ANOMALY (Tmax[°C])', fontsize=12, fontweight='bold')
axs[0].set_xticks(index + 2.5 * bar_width)  # Center ticks
axs[0].set_xticklabels(annual_yendi_1961_1990['year'], rotation=90, fontsize=10, fontweight='bold')
axs[0].grid(True, which='both', linestyle='--', linewidth=1.5)
axs[0].legend(loc='best')

# 2nd subplot: Anomalies for 1991-2020
axs[1].bar(index, annual_yendi_1991_2020['Anomaly'], width=bar_width, label="Yendi")
axs[1].bar(index + bar_width, annual_Navrongo_1991_2020['Anomaly'], width=bar_width, label="Navrongo")
axs[1].bar(index + 2 * bar_width, annual_Wa_1991_2020['Anomaly'], width=bar_width, label="Wa")
axs[1].bar(index + 3 * bar_width, annual_Bole_1991_2020['Anomaly'], width=bar_width, label="Bole")
axs[1].bar(index + 4 * bar_width, annual_Walewale_1991_2020['Anomaly'], width=bar_width, label="Walewale")
axs[1].bar(index + 5 * bar_width, annual_Tamale_1991_2020['Anomaly'], width=bar_width, label="Tamale")

# Add a horizontal line at y=0 (zero anomaly line)
axs[1].axhline(y=0, color='black', linestyle='--', linewidth=1.5)

# Set title and labels for the second subplot
axs[1].set_title('1991-2020', fontsize=14, fontweight='bold')
axs[1].set_xlabel('YEAR', fontsize=12, fontweight='bold')
axs[1].set_ylabel('ANOMALY (Tmax[°C])', fontsize=12, fontweight='bold')
axs[1].set_xticks(index + 2.5 * bar_width)  # Center ticks
axs[1].set_xticklabels(annual_yendi_1991_2020['year'], rotation=90, fontsize=10, fontweight='bold')
axs[1].grid(True, which='both', linestyle='--', linewidth=1.5)
axs[1].legend(loc='best')

# Apply a tight layout to prevent overlap
plt.tight_layout(rect=[0, 0, 1, 0.96])  # Adjusting for suptitle
#plt.savefig('TEMP_ANOMALIES.png', bbox_inches='tight', dpi=500)
plt.show()
